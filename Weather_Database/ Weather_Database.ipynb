# %% [markdown]
# # Deliverable 1. Retrieve Weather Data

# %%
# Import the requests library.
import requests
import time
from datetime import datetime
import random
from citipy import citipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import the API key.
#from config import weather_api_key
import os
from dotenv import load_dotenv
load_dotenv()
weather_api_key = os.getenv("weather_api_key")

# %%
#2,000 random latitudes and longitudes
lat=np.random.uniform(-90.000,40.000, size=2000)
lng=np.random.uniform(-90.000,300.000, size=2000)
lat_lng=zip(lat,lng)
coordinates=list(lat_lng)
#for coordinate in coordinates:
    #print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          #citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list for holding the cities.
cities=[]
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 555

# %%
#API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

city_url = url + "&q=" + city.replace(" ","+")
city_weather = requests.get(city_url).json()

city_weather["weather"][0]["description"]
city_weather
# Out:
# {'coord': {'lon': 10.25, 'lat': 19.75},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 93.63,
#   'feels_like': 89.02,
#   'temp_min': 93.63,
#   'temp_max': 93.63,
#   'pressure': 1007,
#   'humidity': 11,
#   'sea_level': 1007,
#   'grnd_level': 953},
#  'visibility': 10000,
#  'wind': {'speed': 7.38, 'deg': 331, 'gust': 7.65},
#  'clouds': {'all': 25},
#  'dt': 1659206417,
#  'sys': {'country': 'NE', 'sunrise': 1659156837, 'sunset': 1659203805},
#  'timezone': 3600,
#  'id': 2448083,
#  'name': 'Agadez',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description
                          
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tolaga bay
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | nishihara
# Processing Record 5 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 1 | lata
# Processing Record 7 of Set 1 | asau
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | dunedin
# Processing Record 10 of Set 1 | banda aceh
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | balikpapan
# Processing Record 19 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | olinda
# Processing Record 22 of Set 1 | saint-georges
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | beringovskiy
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | wuchi
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | boa vista
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | quatre cocos
# Processing Record 31 of Set 1 | sandy bay
# Processing Record 32 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 1 | okato
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 1 | gore
# Processing Record 37 of Set 1 | kimamba
# Processing Record 38 of Set 1 | buala
# Processing Record 39 of Set 1 | batticaloa
# Processing Record 40 of Set 1 | banjar
# Processing Record 41 of Set 1 | kavieng
# Processing Record 42 of Set 1 | prado
# Processing Record 43 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 1 | shache
# Processing Record 45 of Set 1 | usevya
# Processing Record 46 of Set 1 | ambanja
# Processing Record 47 of Set 1 | kalmunai
# Processing Record 48 of Set 1 | mantua
# Processing Record 49 of Set 1 | codrington
# Processing Record 50 of Set 1 | jacareacanga
# Processing Record 1 of Set 2 | turbat
# Processing Record 2 of Set 2 | korla
# Processing Record 3 of Set 2 | kalengwa
# Processing Record 4 of Set 2 | bengkulu
# Processing Record 5 of Set 2 | kawalu
# Processing Record 6 of Set 2 | asayita
# City not found. Skipping...
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | esperance
# Processing Record 9 of Set 2 | mitsamiouli
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | sehithwa
# Processing Record 12 of Set 2 | jalu
# Processing Record 13 of Set 2 | champua
# Processing Record 14 of Set 2 | tambura
# Processing Record 15 of Set 2 | sinnamary
# Processing Record 16 of Set 2 | bella union
# Processing Record 17 of Set 2 | kaitangata
# Processing Record 18 of Set 2 | alyangula
# Processing Record 19 of Set 2 | bima
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | saposoa
# Processing Record 22 of Set 2 | geraldton
# Processing Record 23 of Set 2 | ifo
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | wajir
# Processing Record 26 of Set 2 | waipawa
# Processing Record 27 of Set 2 | sao filipe
# Processing Record 28 of Set 2 | hit
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | save
# Processing Record 31 of Set 2 | boyolangu
# Processing Record 32 of Set 2 | sultanpur
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | botro
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 2 | laguna
# Processing Record 38 of Set 2 | thinadhoo
# Processing Record 39 of Set 2 | cururupu
# Processing Record 40 of Set 2 | pishin
# Processing Record 41 of Set 2 | biak
# Processing Record 42 of Set 2 | bilma
# Processing Record 43 of Set 2 | bathsheba
# Processing Record 44 of Set 2 | matanza
# Processing Record 45 of Set 2 | praia
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | luanda
# Processing Record 48 of Set 2 | bisho
# Processing Record 49 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 2 | carnarvon
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | omboue
# Processing Record 3 of Set 3 | salalah
# Processing Record 4 of Set 3 | naze
# Processing Record 5 of Set 3 | namibe
# Processing Record 6 of Set 3 | roebourne
# Processing Record 7 of Set 3 | dongli
# Processing Record 8 of Set 3 | touros
# Processing Record 9 of Set 3 | lakes entrance
# Processing Record 10 of Set 3 | gerash
# Processing Record 11 of Set 3 | matara
# Processing Record 12 of Set 3 | yarada
# Processing Record 13 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 3 | benjamin aceval
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | alta floresta
# Processing Record 17 of Set 3 | byron bay
# Processing Record 18 of Set 3 | arraial do cabo
# Processing Record 19 of Set 3 | cayenne
# Processing Record 20 of Set 3 | qandahar
# City not found. Skipping...
# Processing Record 21 of Set 3 | qingyuan
# Processing Record 22 of Set 3 | sinjah
# City not found. Skipping...
# Processing Record 23 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 24 of Set 3 | pitimbu
# Processing Record 25 of Set 3 | mareeba
# Processing Record 26 of Set 3 | eydhafushi
# Processing Record 27 of Set 3 | poum
# Processing Record 28 of Set 3 | kedougou
# Processing Record 29 of Set 3 | manicore
# Processing Record 30 of Set 3 | chicama
# Processing Record 31 of Set 3 | xichang
# Processing Record 32 of Set 3 | asyut
# Processing Record 33 of Set 3 | waingapu
# Processing Record 34 of Set 3 | nouakchott
# Processing Record 35 of Set 3 | kloulklubed
# Processing Record 36 of Set 3 | sao joao da barra
# Processing Record 37 of Set 3 | kathu
# Processing Record 38 of Set 3 | saldanha
# Processing Record 39 of Set 3 | ahipara
# Processing Record 40 of Set 3 | shimoda
# Processing Record 41 of Set 3 | inhambane
# Processing Record 42 of Set 3 | vao
# Processing Record 43 of Set 3 | padang
# Processing Record 44 of Set 3 | vilhena
# Processing Record 45 of Set 3 | yabrud
# Processing Record 46 of Set 3 | kathmandu
# Processing Record 47 of Set 3 | seydi
# Processing Record 48 of Set 3 | victoria
# Processing Record 49 of Set 3 | ngaoundere
# Processing Record 50 of Set 3 | saint-joseph
# Processing Record 1 of Set 4 | cape town
# Processing Record 2 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 4 | kendari
# Processing Record 4 of Set 4 | nemuro
# Processing Record 5 of Set 4 | rafaela
# Processing Record 6 of Set 4 | dongying
# Processing Record 7 of Set 4 | tsogni
# Processing Record 8 of Set 4 | quelimane
# Processing Record 9 of Set 4 | sabang
# Processing Record 10 of Set 4 | xiongshi
# City not found. Skipping...
# Processing Record 11 of Set 4 | mizan teferi
# Processing Record 12 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 4 | mackay
# Processing Record 14 of Set 4 | labuhan
# Processing Record 15 of Set 4 | mananjary
# Processing Record 16 of Set 4 | beloha
# Processing Record 17 of Set 4 | adrar
# Processing Record 18 of Set 4 | kruisfontein
# Processing Record 19 of Set 4 | dondo
# Processing Record 20 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 4 | marawi
# Processing Record 22 of Set 4 | marsabit
# Processing Record 23 of Set 4 | qujing
# Processing Record 24 of Set 4 | kulu
# Processing Record 25 of Set 4 | pokhara
# Processing Record 26 of Set 4 | mount gambier
# Processing Record 27 of Set 4 | chikhli
# Processing Record 28 of Set 4 | gisborne
# Processing Record 29 of Set 4 | jinchang
# Processing Record 30 of Set 4 | rayachoti
# Processing Record 31 of Set 4 | porirua
# Processing Record 32 of Set 4 | jimma
# Processing Record 33 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 34 of Set 4 | rawson
# Processing Record 35 of Set 4 | siderno
# Processing Record 36 of Set 4 | konispol
# Processing Record 37 of Set 4 | jian
# Processing Record 38 of Set 4 | porto novo
# Processing Record 39 of Set 4 | new norfolk
# Processing Record 40 of Set 4 | pingliang
# Processing Record 41 of Set 4 | krabi
# Processing Record 42 of Set 4 | atar
# Processing Record 43 of Set 4 | sembakung
# Processing Record 44 of Set 4 | kiama
# Processing Record 45 of Set 4 | hamilton
# Processing Record 46 of Set 4 | sheopur
# Processing Record 47 of Set 4 | doha
# Processing Record 48 of Set 4 | iguape
# Processing Record 49 of Set 4 | surin
# Processing Record 50 of Set 4 | mar del plata
# Processing Record 1 of Set 5 | rio grande
# Processing Record 2 of Set 5 | sungairaya
# Processing Record 3 of Set 5 | sungai padi
# Processing Record 4 of Set 5 | kieta
# Processing Record 5 of Set 5 | kimbe
# Processing Record 6 of Set 5 | vanimo
# Processing Record 7 of Set 5 | nanning
# Processing Record 8 of Set 5 | coquimbo
# Processing Record 9 of Set 5 | saint-francois
# Processing Record 10 of Set 5 | samarai
# Processing Record 11 of Set 5 | vila velha
# Processing Record 12 of Set 5 | yulara
# Processing Record 13 of Set 5 | sao joao de pirabas
# Processing Record 14 of Set 5 | sri aman
# Processing Record 15 of Set 5 | severo-kurilsk
# Processing Record 16 of Set 5 | gizo
# Processing Record 17 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 18 of Set 5 | honiara
# Processing Record 19 of Set 5 | nikolskoye
# Processing Record 20 of Set 5 | caravelas
# Processing Record 21 of Set 5 | pimenta bueno
# Processing Record 22 of Set 5 | mahibadhoo
# Processing Record 23 of Set 5 | kroya
# Processing Record 24 of Set 5 | necochea
# Processing Record 25 of Set 5 | lodwar
# Processing Record 26 of Set 5 | guasdualito
# Processing Record 27 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 5 | gualaquiza
# Processing Record 29 of Set 5 | tuatapere
# Processing Record 30 of Set 5 | ranong
# Processing Record 31 of Set 5 | kavaratti
# Processing Record 32 of Set 5 | howard springs
# Processing Record 33 of Set 5 | santiago
# Processing Record 34 of Set 5 | hasaki
# Processing Record 35 of Set 5 | comodoro rivadavia
# Processing Record 36 of Set 5 | srivardhan
# Processing Record 37 of Set 5 | sampit
# Processing Record 38 of Set 5 | sakata
# Processing Record 39 of Set 5 | harsin
# Processing Record 40 of Set 5 | darnah
# Processing Record 41 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 5 | sardarpur
# Processing Record 43 of Set 5 | san lorenzo
# Processing Record 44 of Set 5 | broome
# Processing Record 45 of Set 5 | presidente olegario
# Processing Record 46 of Set 5 | lagos
# Processing Record 47 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 5 | shitanjing
# Processing Record 49 of Set 5 | itarema
# Processing Record 50 of Set 5 | taoudenni
# Processing Record 1 of Set 6 | bombay
# Processing Record 2 of Set 6 | san francisco
# Processing Record 3 of Set 6 | meulaboh
# Processing Record 4 of Set 6 | mandla
# Processing Record 5 of Set 6 | moroni
# Processing Record 6 of Set 6 | kasongo
# Processing Record 7 of Set 6 | portel
# Processing Record 8 of Set 6 | tahta
# Processing Record 9 of Set 6 | barentu
# Processing Record 10 of Set 6 | cidreira
# Processing Record 11 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 12 of Set 6 | namatanai
# Processing Record 13 of Set 6 | airai
# Processing Record 14 of Set 6 | gwadar
# Processing Record 15 of Set 6 | eyl
# Processing Record 16 of Set 6 | bambari
# Processing Record 17 of Set 6 | albania
# Processing Record 18 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 6 | carupano
# Processing Record 20 of Set 6 | torbay
# Processing Record 21 of Set 6 | santa marta
# Processing Record 22 of Set 6 | te anau
# Processing Record 23 of Set 6 | lalpur
# Processing Record 24 of Set 6 | russell
# Processing Record 25 of Set 6 | kupang
# Processing Record 26 of Set 6 | richards bay
# Processing Record 27 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 6 | chenghai
# Processing Record 29 of Set 6 | pandaria
# Processing Record 30 of Set 6 | goderich
# Processing Record 31 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 6 | bocas del toro
# Processing Record 33 of Set 6 | alice springs
# Processing Record 34 of Set 6 | luderitz
# Processing Record 35 of Set 6 | boca do acre
# Processing Record 36 of Set 6 | portland
# Processing Record 37 of Set 6 | pandan
# Processing Record 38 of Set 6 | huoqiu
# Processing Record 39 of Set 6 | myitkyina
# Processing Record 40 of Set 6 | sidi ali
# Processing Record 41 of Set 6 | kalangala
# Processing Record 42 of Set 6 | faya
# Processing Record 43 of Set 6 | flinders
# Processing Record 44 of Set 6 | lorengau
# Processing Record 45 of Set 6 | nalut
# Processing Record 46 of Set 6 | young
# Processing Record 47 of Set 6 | mount isa
# Processing Record 48 of Set 6 | gat
# Processing Record 49 of Set 6 | luena
# Processing Record 50 of Set 6 | black river
# Processing Record 1 of Set 7 | aquin
# Processing Record 2 of Set 7 | sola
# Processing Record 3 of Set 7 | upington
# Processing Record 4 of Set 7 | morant bay
# Processing Record 5 of Set 7 | luwuk
# Processing Record 6 of Set 7 | bwanga
# Processing Record 7 of Set 7 | bueno brandao
# Processing Record 8 of Set 7 | birjand
# Processing Record 9 of Set 7 | tagusao
# Processing Record 10 of Set 7 | vila franca do campo
# Processing Record 11 of Set 7 | chumphon
# Processing Record 12 of Set 7 | dzaoudzi
# Processing Record 13 of Set 7 | taunggyi
# Processing Record 14 of Set 7 | nabire
# Processing Record 15 of Set 7 | mosetse
# Processing Record 16 of Set 7 | huarmey
# Processing Record 17 of Set 7 | warrenton
# Processing Record 18 of Set 7 | fanai
# Processing Record 19 of Set 7 | sydney
# Processing Record 20 of Set 7 | hongjiang
# Processing Record 21 of Set 7 | middelburg
# Processing Record 22 of Set 7 | saint-pierre
# Processing Record 23 of Set 7 | tiznit
# Processing Record 24 of Set 7 | nouadhibou
# Processing Record 25 of Set 7 | anloga
# Processing Record 26 of Set 7 | panguna
# Processing Record 27 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 7 | lasa
# Processing Record 29 of Set 7 | zhuanghe
# Processing Record 30 of Set 7 | mbale
# Processing Record 31 of Set 7 | kashi
# Processing Record 32 of Set 7 | mahon
# Processing Record 33 of Set 7 | paita
# Processing Record 34 of Set 7 | tamandare
# Processing Record 35 of Set 7 | ankang
# Processing Record 36 of Set 7 | koulikoro
# Processing Record 37 of Set 7 | burewala
# Processing Record 38 of Set 7 | maracaibo
# Processing Record 39 of Set 7 | nampula
# Processing Record 40 of Set 7 | saint george
# Processing Record 41 of Set 7 | ancud
# Processing Record 42 of Set 7 | bandarbeyla
# Processing Record 43 of Set 7 | tamworth
# Processing Record 44 of Set 7 | port blair
# Processing Record 45 of Set 7 | caninde de sao francisco
# Processing Record 46 of Set 7 | kirakira
# Processing Record 47 of Set 7 | cacapava do sul
# Processing Record 48 of Set 7 | iquique
# Processing Record 49 of Set 7 | tocopilla
# Processing Record 50 of Set 7 | anshun
# Processing Record 1 of Set 8 | pinhao
# Processing Record 2 of Set 8 | santiago del estero
# Processing Record 3 of Set 8 | tessalit
# Processing Record 4 of Set 8 | tabriz
# Processing Record 5 of Set 8 | aljezur
# Processing Record 6 of Set 8 | guhagar
# Processing Record 7 of Set 8 | albina
# Processing Record 8 of Set 8 | peruibe
# Processing Record 9 of Set 8 | ruwi
# Processing Record 10 of Set 8 | hluti
# Processing Record 11 of Set 8 | baturaja
# Processing Record 12 of Set 8 | bodden town
# Processing Record 13 of Set 8 | chongwe
# Processing Record 14 of Set 8 | amalapuram
# Processing Record 15 of Set 8 | maua
# Processing Record 16 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 17 of Set 8 | abu kamal
# Processing Record 18 of Set 8 | arinos
# Processing Record 19 of Set 8 | dibaya
# City not found. Skipping...
# Processing Record 20 of Set 8 | viedma
# Processing Record 21 of Set 8 | pamanukan
# Processing Record 22 of Set 8 | kerki
# City not found. Skipping...
# Processing Record 23 of Set 8 | margate
# Processing Record 24 of Set 8 | jiwani
# Processing Record 25 of Set 8 | benguela
# Processing Record 26 of Set 8 | gayeri
# Processing Record 27 of Set 8 | kelo
# Processing Record 28 of Set 8 | valdosta
# Processing Record 29 of Set 8 | matay
# Processing Record 30 of Set 8 | shingu
# Processing Record 31 of Set 8 | menongue
# Processing Record 32 of Set 8 | quarai
# Processing Record 33 of Set 8 | umm lajj
# Processing Record 34 of Set 8 | santa maria
# Processing Record 35 of Set 8 | bambanglipuro
# Processing Record 36 of Set 8 | camocim
# Processing Record 37 of Set 8 | laguna de perlas
# Processing Record 38 of Set 8 | zafra
# Processing Record 39 of Set 8 | sabha
# Processing Record 40 of Set 8 | magole
# Processing Record 41 of Set 8 | tallahassee
# Processing Record 42 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 43 of Set 8 | kununurra
# Processing Record 44 of Set 8 | auki
# Processing Record 45 of Set 8 | kuroiso
# Processing Record 46 of Set 8 | presidencia roque saenz pena
# Processing Record 47 of Set 8 | isangel
# Processing Record 48 of Set 8 | soyo
# Processing Record 49 of Set 8 | sur
# Processing Record 50 of Set 8 | batemans bay
# Processing Record 1 of Set 9 | camacha
# Processing Record 2 of Set 9 | karratha
# Processing Record 3 of Set 9 | port lincoln
# Processing Record 4 of Set 9 | bhinga
# Processing Record 5 of Set 9 | mercedes
# Processing Record 6 of Set 9 | camacupa
# Processing Record 7 of Set 9 | eskisehir
# Processing Record 8 of Set 9 | kekri
# Processing Record 9 of Set 9 | plettenberg bay
# Processing Record 10 of Set 9 | burgersdorp
# Processing Record 11 of Set 9 | surab
# Processing Record 12 of Set 9 | sorong
# Processing Record 13 of Set 9 | magaria
# Processing Record 14 of Set 9 | cockburn town
# Processing Record 15 of Set 9 | puerto ayora
# Processing Record 16 of Set 9 | acarau
# Processing Record 17 of Set 9 | balkanabat
# Processing Record 18 of Set 9 | norsup
# Processing Record 19 of Set 9 | vallenar
# Processing Record 20 of Set 9 | jalesar
# Processing Record 21 of Set 9 | tsabong
# Processing Record 22 of Set 9 | qingdao
# Processing Record 23 of Set 9 | oistins
# Processing Record 24 of Set 9 | fort walton beach
# Processing Record 25 of Set 9 | villazon
# Processing Record 26 of Set 9 | bonthe
# Processing Record 27 of Set 9 | cumana
# Processing Record 28 of Set 9 | mecca
# Processing Record 29 of Set 9 | carutapera
# Processing Record 30 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 31 of Set 9 | murgab
# Processing Record 32 of Set 9 | zaltan
# Processing Record 33 of Set 9 | otane
# Processing Record 34 of Set 9 | tignere
# Processing Record 35 of Set 9 | khandbari
# Processing Record 36 of Set 9 | pousat
# City not found. Skipping...
# Processing Record 37 of Set 9 | damaturu
# Processing Record 38 of Set 9 | ulladulla
# Processing Record 39 of Set 9 | general roca
# Processing Record 40 of Set 9 | mangrol
# Processing Record 41 of Set 9 | kulachi
# Processing Record 42 of Set 9 | uyuni
# Processing Record 43 of Set 9 | merauke
# Processing Record 44 of Set 9 | san roque
# Processing Record 45 of Set 9 | gushikawa
# Processing Record 46 of Set 9 | qui nhon
# Processing Record 47 of Set 9 | lenoir city
# Processing Record 48 of Set 9 | oranjemund
# Processing Record 49 of Set 9 | yei
# Processing Record 50 of Set 9 | desaguadero
# Processing Record 1 of Set 10 | oudtshoorn
# Processing Record 2 of Set 10 | fairmont
# Processing Record 3 of Set 10 | moranbah
# Processing Record 4 of Set 10 | pedasi
# Processing Record 5 of Set 10 | dutse
# Processing Record 6 of Set 10 | ziniare
# Processing Record 7 of Set 10 | guarapari
# Processing Record 8 of Set 10 | henties bay
# Processing Record 9 of Set 10 | wana
# Processing Record 10 of Set 10 | nargana
# Processing Record 11 of Set 10 | nola
# Processing Record 12 of Set 10 | mehtar lam
# Processing Record 13 of Set 10 | port-gentil
# Processing Record 14 of Set 10 | coihaique
# Processing Record 15 of Set 10 | port hedland
# Processing Record 16 of Set 10 | shenjiamen
# Processing Record 17 of Set 10 | chirongui
# Processing Record 18 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 10 | hambantota
# Processing Record 20 of Set 10 | bindura
# Processing Record 21 of Set 10 | farah
# Processing Record 22 of Set 10 | azad shahr
# Processing Record 23 of Set 10 | odweyne
# Processing Record 24 of Set 10 | baglan
# Processing Record 25 of Set 10 | horsham
# Processing Record 26 of Set 10 | san ignacio
# Processing Record 27 of Set 10 | ambalavao
# Processing Record 28 of Set 10 | rondonopolis
# Processing Record 29 of Set 10 | gorontalo
# Processing Record 30 of Set 10 | ambilobe
# Processing Record 31 of Set 10 | oyugis
# Processing Record 32 of Set 10 | dhidhdhoo
# Processing Record 33 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 34 of Set 10 | port macquarie
# Processing Record 35 of Set 10 | saint-louis
# Processing Record 36 of Set 10 | simav
# Processing Record 37 of Set 10 | kananga
# Processing Record 38 of Set 10 | rio cauto
# Processing Record 39 of Set 10 | kinablangan
# Processing Record 40 of Set 10 | ngunguru
# Processing Record 41 of Set 10 | nichinan
# Processing Record 42 of Set 10 | vredendal
# Processing Record 43 of Set 10 | zabol
# Processing Record 44 of Set 10 | alexandria
# Processing Record 45 of Set 10 | yumen
# Processing Record 46 of Set 10 | oussouye
# Processing Record 47 of Set 10 | poindimie
# Processing Record 48 of Set 10 | roquetas de mar
# Processing Record 49 of Set 10 | antsohihy
# Processing Record 50 of Set 10 | manavgat
# Processing Record 1 of Set 11 | cartagena
# Processing Record 2 of Set 11 | am timan
# Processing Record 3 of Set 11 | san cristobal
# Processing Record 4 of Set 11 | leh
# Processing Record 5 of Set 11 | japura
# Processing Record 6 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 7 of Set 11 | buluang
# Processing Record 8 of Set 11 | tateyama
# Processing Record 9 of Set 11 | moratuwa
# Processing Record 10 of Set 11 | rincon
# Processing Record 11 of Set 11 | soe
# Processing Record 12 of Set 11 | senanga
# Processing Record 13 of Set 11 | pemangkat
# Processing Record 14 of Set 11 | kisangani
# Processing Record 15 of Set 11 | tezu
# Processing Record 16 of Set 11 | tres arroyos
# Processing Record 17 of Set 11 | lethem
# Processing Record 18 of Set 11 | mae hong son
# Processing Record 19 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 11 | lagunas
# Processing Record 21 of Set 11 | hoi an
# Processing Record 22 of Set 11 | kifri
# Processing Record 23 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 24 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 25 of Set 11 | kambar
# Processing Record 26 of Set 11 | massaguet
# Processing Record 27 of Set 11 | axim
# Processing Record 28 of Set 11 | paracuru
# Processing Record 29 of Set 11 | angoche
# Processing Record 30 of Set 11 | santa fe
# Processing Record 31 of Set 11 | baiao
# Processing Record 32 of Set 11 | kumphawapi
# Processing Record 33 of Set 11 | katsuura
# Processing Record 34 of Set 11 | nelson bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Tolaga Bay -38.3667  178.3000     55.90        78          27
# 1     Port Alfred -33.5906   26.8910     58.84        61          78
# 2          Hobart -42.8794  147.3294     42.26        84         100
# 3       Nishihara  26.1842  127.7558     80.26        94          75
# 4            Lata  40.1629   -8.3327     87.49        43           0
# 5            Asau  46.4333   26.4000     72.52        89          86
# 6        Hermanus -34.4187   19.2345     48.79        80          97
# 7         Dunedin -45.8742  170.5036     41.81        70          99
# 8      Banda Aceh   5.5577   95.3222     80.53        76         100
# 9  Saint-Philippe -21.3585   55.7679     66.22        78          42
#
#    Wind Speed Country Current Description
# 0       15.19      NZ    scattered clouds
# 1       17.31      ZA       broken clouds
# 2        8.05      AU     overcast clouds
# 3        8.05      JP       moderate rain
# 4        7.76      PT           clear sky
# 5        2.75      RO     overcast clouds
# 6        7.94      ZA          light rain
# 7        8.01      NZ     overcast clouds
# 8       12.84      ID     overcast clouds
# 9       15.73      RE    scattered clouds

# %%
new_coloumn_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_coloumn_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Tolaga Bay      NZ -38.3667  178.3000     55.90        78          27
# 1     Port Alfred      ZA -33.5906   26.8910     58.84        61          78
# 2          Hobart      AU -42.8794  147.3294     42.26        84         100
# 3       Nishihara      JP  26.1842  127.7558     80.26        94          75
# 4            Lata      PT  40.1629   -8.3327     87.49        43           0
# 5            Asau      RO  46.4333   26.4000     72.52        89          86
# 6        Hermanus      ZA -34.4187   19.2345     48.79        80          97
# 7         Dunedin      NZ -45.8742  170.5036     41.81        70          99
# 8      Banda Aceh      ID   5.5577   95.3222     80.53        76         100
# 9  Saint-Philippe      RE -21.3585   55.7679     66.22        78          42
#
#    Wind Speed Current Description
# 0       15.19    scattered clouds
# 1       17.31       broken clouds
# 2        8.05     overcast clouds
# 3        8.05       moderate rain
# 4        7.76           clear sky
# 5        2.75     overcast clouds
# 6        7.94          light rain
# 7        8.01     overcast clouds
# 8       12.84     overcast clouds
# 9       15.73    scattered clouds

# %%
file_to_save="../Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(file_to_save, index_label="City ID")
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Tolaga Bay      NZ -38.3667  178.3000     55.90        78          27
# 1     Port Alfred      ZA -33.5906   26.8910     58.84        61          78
# 2          Hobart      AU -42.8794  147.3294     42.26        84         100
# 3       Nishihara      JP  26.1842  127.7558     80.26        94          75
# 4            Lata      PT  40.1629   -8.3327     87.49        43           0
# 5            Asau      RO  46.4333   26.4000     72.52        89          86
# 6        Hermanus      ZA -34.4187   19.2345     48.79        80          97
# 7         Dunedin      NZ -45.8742  170.5036     41.81        70          99
# 8      Banda Aceh      ID   5.5577   95.3222     80.53        76         100
# 9  Saint-Philippe      RE -21.3585   55.7679     66.22        78          42
#
#    Wind Speed Current Description
# 0       15.19    scattered clouds
# 1       17.31       broken clouds
# 2        8.05     overcast clouds
# 3        8.05       moderate rain
# 4        7.76           clear sky
# 5        2.75     overcast clouds
# 6        7.94          light rain
# 7        8.01     overcast clouds
# 8       12.84     overcast clouds
# 9       15.73    scattered clouds
